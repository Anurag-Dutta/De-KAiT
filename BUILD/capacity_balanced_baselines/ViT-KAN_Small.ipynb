# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./50/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 50
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.5924 | train_acc 0.2350 | train_f1 0.1889 | val_loss 1.5852 | val_acc 0.2600 | val_f1 0.2027
# Train 2/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 1.5733 | train_acc 0.2950 | train_f1 0.2482 | val_loss 1.5754 | val_acc 0.2600 | val_f1 0.1969
# Train 3/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 1.5613 | train_acc 0.3300 | train_f1 0.2930 | val_loss 1.5718 | val_acc 0.3600 | val_f1 0.2651
# Train 4/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 1.5177 | train_acc 0.3450 | train_f1 0.3125 | val_loss 1.5717 | val_acc 0.3800 | val_f1 0.3091
# Train 5/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 1.5227 | train_acc 0.3600 | train_f1 0.3187 | val_loss 1.5732 | val_acc 0.3000 | val_f1 0.2248
# Train 6/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 1.5048 | train_acc 0.3350 | train_f1 0.2945 | val_loss 1.5687 | val_acc 0.2800 | val_f1 0.2107
# Train 7/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 1.5160 | train_acc 0.3450 | train_f1 0.2860 | val_loss 1.5594 | val_acc 0.2800 | val_f1 0.2105
# Train 8/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 1.5049 | train_acc 0.3700 | train_f1 0.3214 | val_loss 1.5551 | val_acc 0.3000 | val_f1 0.2250
# Train 9/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 1.4865 | train_acc 0.3550 | train_f1 0.2968 | val_loss 1.5488 | val_acc 0.2600 | val_f1 0.1905
# Train 10/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 1.4828 | train_acc 0.3850 | train_f1 0.3415 | val_loss 1.5441 | val_acc 0.2800 | val_f1 0.2078
# Train 11/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 1.4568 | train_acc 0.3850 | train_f1 0.3453 | val_loss 1.5409 | val_acc 0.2600 | val_f1 0.1895
# Train 12/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 1.4890 | train_acc 0.3750 | train_f1 0.3209 | val_loss 1.5373 | val_acc 0.2800 | val_f1 0.2071
# Train 13/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 1.4327 | train_acc 0.4250 | train_f1 0.3840 | val_loss 1.5259 | val_acc 0.3000 | val_f1 0.2500
# Train 14/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 1.4196 | train_acc 0.4050 | train_f1 0.3507 | val_loss 1.5166 | val_acc 0.3000 | val_f1 0.2631
# Train 15/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 1.4263 | train_acc 0.4000 | train_f1 0.3518 | val_loss 1.5055 | val_acc 0.2800 | val_f1 0.2116
# Train 16/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 1.4039 | train_acc 0.4200 | train_f1 0.3693 | val_loss 1.4682 | val_acc 0.2800 | val_f1 0.2435
# Train 17/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 1.3802 | train_acc 0.4200 | train_f1 0.3759 | val_loss 1.4744 | val_acc 0.2800 | val_f1 0.2435
# Train 18/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 1.3818 | train_acc 0.4500 | train_f1 0.4015 | val_loss 1.4468 | val_acc 0.2800 | val_f1 0.2347
# Train 19/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 1.3594 | train_acc 0.4250 | train_f1 0.3811 | val_loss 1.4426 | val_acc 0.3200 | val_f1 0.2864
# Train 20/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 1.3182 | train_acc 0.4700 | train_f1 0.4177 | val_loss 1.5136 | val_acc 0.2800 | val_f1 0.2106
# Val final/final:   0%|          | 0/2 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 19.50 sec
#
# Final Evaluation
# Val Loss   : 1.5717
# Val Acc    : 0.3800
# Val Prec   : 0.4204
# Val Recall : 0.3800
# Val F1     : 0.3091
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.3333    0.6000    0.4286        10
#          chat     0.0000    0.0000    0.0000        10
# file_transfer     0.3571    0.5000    0.4167        10
#         video     1.0000    0.1000    0.1818        10
#          voip     0.4118    0.7000    0.5185        10
#
#      accuracy                         0.3800        50
#     macro avg     0.4204    0.3800    0.3091        50
#  weighted avg     0.4204    0.3800    0.3091        50
#
# Confusion Matrix:
# [[6 0 4 0 0]
#  [5 0 1 0 4]
#  [2 0 5 0 3]
#  [5 0 1 1 3]
#  [0 0 3 0 7]]
# c:\Users\rscha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\rscha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\rscha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./100/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 100
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.5815 | train_acc 0.2450 | train_f1 0.2216 | val_loss 1.4715 | val_acc 0.3100 | val_f1 0.2262
# Train 2/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 1.5377 | train_acc 0.3300 | train_f1 0.3269 | val_loss 1.4131 | val_acc 0.3700 | val_f1 0.2918
# Train 3/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 1.5084 | train_acc 0.3400 | train_f1 0.3197 | val_loss 1.3758 | val_acc 0.3900 | val_f1 0.3014
# Train 4/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 1.4953 | train_acc 0.3450 | train_f1 0.3035 | val_loss 1.3470 | val_acc 0.4200 | val_f1 0.3234
# Train 5/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 1.4684 | train_acc 0.3675 | train_f1 0.3389 | val_loss 1.3214 | val_acc 0.5000 | val_f1 0.4737
# Train 6/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 1.4528 | train_acc 0.3850 | train_f1 0.3642 | val_loss 1.2880 | val_acc 0.4500 | val_f1 0.4315
# Train 7/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 1.4358 | train_acc 0.3875 | train_f1 0.3702 | val_loss 1.2692 | val_acc 0.4500 | val_f1 0.4013
# Train 8/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 1.4206 | train_acc 0.3950 | train_f1 0.3783 | val_loss 1.2445 | val_acc 0.4700 | val_f1 0.4298
# Train 9/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 1.3961 | train_acc 0.4150 | train_f1 0.3852 | val_loss 1.2165 | val_acc 0.5100 | val_f1 0.4849
# Train 10/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 1.3809 | train_acc 0.4250 | train_f1 0.4124 | val_loss 1.2029 | val_acc 0.5300 | val_f1 0.5165
# Train 11/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 1.3549 | train_acc 0.4350 | train_f1 0.4235 | val_loss 1.1888 | val_acc 0.5400 | val_f1 0.5169
# Train 12/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 1.3364 | train_acc 0.4400 | train_f1 0.4164 | val_loss 1.1740 | val_acc 0.5500 | val_f1 0.5398
# Train 13/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 1.3316 | train_acc 0.4050 | train_f1 0.3816 | val_loss 1.1358 | val_acc 0.5000 | val_f1 0.4654
# Train 14/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 1.3021 | train_acc 0.4325 | train_f1 0.4112 | val_loss 1.1127 | val_acc 0.5000 | val_f1 0.4701
# Train 15/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 1.2929 | train_acc 0.4550 | train_f1 0.4493 | val_loss 1.1036 | val_acc 0.5800 | val_f1 0.5784
# Train 16/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 1.2509 | train_acc 0.4950 | train_f1 0.4844 | val_loss 1.1025 | val_acc 0.5700 | val_f1 0.5652
# Train 17/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 1.2386 | train_acc 0.4600 | train_f1 0.4599 | val_loss 1.1075 | val_acc 0.5700 | val_f1 0.5705
# Train 18/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 1.2125 | train_acc 0.4975 | train_f1 0.4871 | val_loss 1.0755 | val_acc 0.5400 | val_f1 0.5239
# Train 19/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 1.2002 | train_acc 0.4800 | train_f1 0.4764 | val_loss 1.0833 | val_acc 0.5200 | val_f1 0.5142
# Train 20/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 1.2139 | train_acc 0.4750 | train_f1 0.4562 | val_loss 1.0705 | val_acc 0.5500 | val_f1 0.5422
# Val final/final:   0%|          | 0/4 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 42.61 sec
#
# Final Evaluation
# Val Loss   : 1.1036
# Val Acc    : 0.5800
# Val Prec   : 0.5801
# Val Recall : 0.5800
# Val F1     : 0.5784
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.5294    0.4500    0.4865        20
#          chat     0.4762    0.5000    0.4878        20
# file_transfer     0.7619    0.8000    0.7805        20
#         video     0.5217    0.6000    0.5581        20
#          voip     0.6111    0.5500    0.5789        20
#
#      accuracy                         0.5800       100
#     macro avg     0.5801    0.5800    0.5784       100
#  weighted avg     0.5801    0.5800    0.5784       100
#
# Confusion Matrix:
# [[ 9  6  1  4  0]
#  [ 5 10  1  3  1]
#  [ 1  0 16  1  2]
#  [ 0  4  0 12  4]
#  [ 2  1  3  3 11]]

# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./200/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 200
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.5584 | train_acc 0.2875 | train_f1 0.2624 | val_loss 1.4772 | val_acc 0.4350 | val_f1 0.3555
# Train 2/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 1.4852 | train_acc 0.3650 | train_f1 0.3448 | val_loss 1.4470 | val_acc 0.3550 | val_f1 0.2994
# Train 3/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 1.4405 | train_acc 0.3925 | train_f1 0.3646 | val_loss 1.4190 | val_acc 0.4050 | val_f1 0.3725
# Train 4/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 1.4182 | train_acc 0.3925 | train_f1 0.3539 | val_loss 1.4102 | val_acc 0.4150 | val_f1 0.3511
# Train 5/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 1.3963 | train_acc 0.4125 | train_f1 0.3809 | val_loss 1.3938 | val_acc 0.4500 | val_f1 0.4275
# Train 6/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 1.3771 | train_acc 0.4387 | train_f1 0.4174 | val_loss 1.3775 | val_acc 0.4450 | val_f1 0.4116
# Train 7/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 1.3607 | train_acc 0.4350 | train_f1 0.4123 | val_loss 1.3790 | val_acc 0.4450 | val_f1 0.4139
# Train 8/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 1.3239 | train_acc 0.4562 | train_f1 0.4450 | val_loss 1.3168 | val_acc 0.4800 | val_f1 0.4591
# Train 9/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 1.2890 | train_acc 0.4850 | train_f1 0.4741 | val_loss 1.2425 | val_acc 0.5200 | val_f1 0.5136
# Train 10/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 1.2543 | train_acc 0.4975 | train_f1 0.4911 | val_loss 1.2365 | val_acc 0.5400 | val_f1 0.5312
# Train 11/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 1.1999 | train_acc 0.5487 | train_f1 0.5445 | val_loss 1.2143 | val_acc 0.5600 | val_f1 0.5351
# Train 12/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 1.1730 | train_acc 0.5587 | train_f1 0.5513 | val_loss 1.1836 | val_acc 0.5800 | val_f1 0.5646
# Train 13/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 1.1409 | train_acc 0.5713 | train_f1 0.5648 | val_loss 1.1695 | val_acc 0.5600 | val_f1 0.5497
# Train 14/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 1.1213 | train_acc 0.5837 | train_f1 0.5786 | val_loss 1.1345 | val_acc 0.5900 | val_f1 0.5749
# Train 15/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 1.0882 | train_acc 0.5863 | train_f1 0.5758 | val_loss 1.1156 | val_acc 0.6100 | val_f1 0.5904
# Train 16/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 1.0551 | train_acc 0.6075 | train_f1 0.5985 | val_loss 1.1469 | val_acc 0.6000 | val_f1 0.5843
# Train 17/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 1.0315 | train_acc 0.6200 | train_f1 0.6116 | val_loss 1.0859 | val_acc 0.6050 | val_f1 0.5856
# Train 18/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 1.0187 | train_acc 0.6188 | train_f1 0.6074 | val_loss 1.1010 | val_acc 0.5750 | val_f1 0.5481
# Train 19/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 0.9910 | train_acc 0.6462 | train_f1 0.6370 | val_loss 1.0528 | val_acc 0.6200 | val_f1 0.6041
# Train 20/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 0.9656 | train_acc 0.6425 | train_f1 0.6308 | val_loss 1.0259 | val_acc 0.6250 | val_f1 0.6020
# Val final/final:   0%|          | 0/7 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 86.86 sec
#
# Final Evaluation
# Val Loss   : 1.0528
# Val Acc    : 0.6200
# Val Prec   : 0.6291
# Val Recall : 0.6200
# Val F1     : 0.6041
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.5667    0.8500    0.6800        40
#          chat     0.5833    0.3500    0.4375        40
# file_transfer     0.6071    0.8500    0.7083        40
#         video     0.6071    0.4250    0.5000        40
#          voip     0.7812    0.6250    0.6944        40
#
#      accuracy                         0.6200       200
#     macro avg     0.6291    0.6200    0.6041       200
#  weighted avg     0.6291    0.6200    0.6041       200
#
# Confusion Matrix:
# [[34  4  1  1  0]
#  [19 14  3  4  0]
#  [ 4  1 34  1  0]
#  [ 2  3 11 17  7]
#  [ 1  2  7  5 25]]

# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./400/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 400
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.5296 | train_acc 0.3231 | train_f1 0.3122 | val_loss 1.4626 | val_acc 0.4225 | val_f1 0.4039
# Train 2/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 1.4513 | train_acc 0.3956 | train_f1 0.3755 | val_loss 1.4182 | val_acc 0.3750 | val_f1 0.2795
# Train 3/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 1.4056 | train_acc 0.4125 | train_f1 0.3838 | val_loss 1.3420 | val_acc 0.4075 | val_f1 0.3383
# Train 4/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 1.3488 | train_acc 0.4263 | train_f1 0.4043 | val_loss 1.2224 | val_acc 0.4850 | val_f1 0.4745
# Train 5/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 1.2641 | train_acc 0.4800 | train_f1 0.4670 | val_loss 1.1595 | val_acc 0.5375 | val_f1 0.5212
# Train 6/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 1.2055 | train_acc 0.5144 | train_f1 0.5016 | val_loss 1.1553 | val_acc 0.5425 | val_f1 0.5303
# Train 7/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 1.1601 | train_acc 0.5344 | train_f1 0.5229 | val_loss 1.0932 | val_acc 0.5525 | val_f1 0.5140
# Train 8/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 1.1021 | train_acc 0.5813 | train_f1 0.5691 | val_loss 1.0268 | val_acc 0.6200 | val_f1 0.6026
# Train 9/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 1.0667 | train_acc 0.5781 | train_f1 0.5686 | val_loss 0.9874 | val_acc 0.6300 | val_f1 0.6137
# Train 10/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 1.0178 | train_acc 0.6019 | train_f1 0.5934 | val_loss 0.9430 | val_acc 0.6550 | val_f1 0.6401
# Train 11/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 0.9818 | train_acc 0.6162 | train_f1 0.6079 | val_loss 0.9147 | val_acc 0.6650 | val_f1 0.6534
# Train 12/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 0.9446 | train_acc 0.6406 | train_f1 0.6348 | val_loss 0.8837 | val_acc 0.6625 | val_f1 0.6525
# Train 13/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 0.9121 | train_acc 0.6462 | train_f1 0.6403 | val_loss 0.8354 | val_acc 0.7025 | val_f1 0.6999
# Train 14/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 0.8705 | train_acc 0.6694 | train_f1 0.6643 | val_loss 0.7853 | val_acc 0.7125 | val_f1 0.7092
# Train 15/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 0.8377 | train_acc 0.6781 | train_f1 0.6749 | val_loss 0.7836 | val_acc 0.7125 | val_f1 0.7049
# Train 16/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 0.7841 | train_acc 0.7150 | train_f1 0.7119 | val_loss 0.7449 | val_acc 0.7125 | val_f1 0.7066
# Train 17/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 0.7661 | train_acc 0.7206 | train_f1 0.7175 | val_loss 0.7118 | val_acc 0.7350 | val_f1 0.7326
# Train 18/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 0.7321 | train_acc 0.7188 | train_f1 0.7170 | val_loss 0.6822 | val_acc 0.7375 | val_f1 0.7370
# Train 19/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 0.7155 | train_acc 0.7238 | train_f1 0.7214 | val_loss 0.6599 | val_acc 0.7625 | val_f1 0.7615
# Train 20/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 0.6868 | train_acc 0.7431 | train_f1 0.7416 | val_loss 0.6208 | val_acc 0.7700 | val_f1 0.7688
# Val final/final:   0%|          | 0/13 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 180.17 sec
#
# Final Evaluation
# Val Loss   : 0.6208
# Val Acc    : 0.7700
# Val Prec   : 0.7813
# Val Recall : 0.7700
# Val F1     : 0.7688
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.6635    0.8625    0.7500        80
#          chat     0.7581    0.5875    0.6620        80
# file_transfer     0.7500    0.8625    0.8023        80
#         video     0.8219    0.7500    0.7843        80
#          voip     0.9130    0.7875    0.8456        80
#
#      accuracy                         0.7700       400
#     macro avg     0.7813    0.7700    0.7688       400
#  weighted avg     0.7813    0.7700    0.7688       400
#
# Confusion Matrix:
# [[69  7  1  0  3]
#  [26 47  2  4  1]
#  [ 7  0 69  4  0]
#  [ 0  3 15 60  2]
#  [ 2  5  5  5 63]]

# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./500/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 500
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.5127 | train_acc 0.3310 | train_f1 0.3127 | val_loss 1.4917 | val_acc 0.3620 | val_f1 0.3057
# Train 2/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 1.4271 | train_acc 0.3995 | train_f1 0.3676 | val_loss 1.4456 | val_acc 0.3980 | val_f1 0.3558
# Train 3/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 1.3540 | train_acc 0.4350 | train_f1 0.4214 | val_loss 1.3139 | val_acc 0.4580 | val_f1 0.4597
# Train 4/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 1.2500 | train_acc 0.4795 | train_f1 0.4733 | val_loss 1.2941 | val_acc 0.4760 | val_f1 0.4800
# Train 5/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 1.1819 | train_acc 0.5445 | train_f1 0.5369 | val_loss 1.1910 | val_acc 0.5360 | val_f1 0.5183
# Train 6/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 1.1191 | train_acc 0.5690 | train_f1 0.5603 | val_loss 1.2230 | val_acc 0.4960 | val_f1 0.4674
# Train 7/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 1.0797 | train_acc 0.5870 | train_f1 0.5777 | val_loss 1.0664 | val_acc 0.5920 | val_f1 0.5856
# Train 8/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 1.0132 | train_acc 0.6190 | train_f1 0.6111 | val_loss 1.0155 | val_acc 0.6120 | val_f1 0.6067
# Train 9/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 0.9806 | train_acc 0.6195 | train_f1 0.6130 | val_loss 0.9764 | val_acc 0.6240 | val_f1 0.6136
# Train 10/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 0.9268 | train_acc 0.6535 | train_f1 0.6478 | val_loss 0.9250 | val_acc 0.6520 | val_f1 0.6396
# Train 11/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 0.8696 | train_acc 0.6810 | train_f1 0.6759 | val_loss 0.8952 | val_acc 0.6460 | val_f1 0.6350
# Train 12/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 0.8327 | train_acc 0.6945 | train_f1 0.6909 | val_loss 0.8709 | val_acc 0.6760 | val_f1 0.6691
# Train 13/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 0.7917 | train_acc 0.7130 | train_f1 0.7093 | val_loss 0.8737 | val_acc 0.6700 | val_f1 0.6593
# Train 14/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 0.7424 | train_acc 0.7270 | train_f1 0.7250 | val_loss 0.7674 | val_acc 0.7160 | val_f1 0.7107
# Train 15/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 0.6971 | train_acc 0.7455 | train_f1 0.7422 | val_loss 0.7193 | val_acc 0.7500 | val_f1 0.7521
# Train 16/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 0.6436 | train_acc 0.7640 | train_f1 0.7623 | val_loss 0.6836 | val_acc 0.7400 | val_f1 0.7376
# Train 17/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 0.6245 | train_acc 0.7710 | train_f1 0.7685 | val_loss 0.6939 | val_acc 0.7280 | val_f1 0.7316
# Train 18/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 0.5739 | train_acc 0.7960 | train_f1 0.7950 | val_loss 0.6063 | val_acc 0.7620 | val_f1 0.7618
# Train 19/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 0.5420 | train_acc 0.8030 | train_f1 0.8014 | val_loss 0.6085 | val_acc 0.7840 | val_f1 0.7788
# Train 20/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 0.5045 | train_acc 0.8235 | train_f1 0.8215 | val_loss 0.5407 | val_acc 0.7980 | val_f1 0.7994
# Val final/final:   0%|          | 0/16 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 221.68 sec
#
# Final Evaluation
# Val Loss   : 0.5407
# Val Acc    : 0.7980
# Val Prec   : 0.8088
# Val Recall : 0.7980
# Val F1     : 0.7994
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.6718    0.8800    0.7619       100
#          chat     0.7021    0.6600    0.6804       100
# file_transfer     0.8889    0.8000    0.8421       100
#         video     0.9271    0.8900    0.9082       100
#          voip     0.8539    0.7600    0.8042       100
#
#      accuracy                         0.7980       500
#     macro avg     0.8088    0.7980    0.7994       500
#  weighted avg     0.8088    0.7980    0.7994       500
#
# Confusion Matrix:
# [[88  8  0  2  2]
#  [34 66  0  0  0]
#  [ 9  3 80  1  7]
#  [ 0  0  7 89  4]
#  [ 0 17  3  4 76]]

# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./800/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 800
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.5005 | train_acc 0.3194 | train_f1 0.3029 | val_loss 1.4368 | val_acc 0.3937 | val_f1 0.3489
# Train 2/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 1.3900 | train_acc 0.4044 | train_f1 0.3817 | val_loss 1.3135 | val_acc 0.4387 | val_f1 0.3971
# Train 3/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 1.2521 | train_acc 0.4894 | train_f1 0.4817 | val_loss 1.2140 | val_acc 0.5050 | val_f1 0.4832
# Train 4/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 1.1563 | train_acc 0.5481 | train_f1 0.5363 | val_loss 1.0862 | val_acc 0.5650 | val_f1 0.5593
# Train 5/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 1.0589 | train_acc 0.5922 | train_f1 0.5820 | val_loss 1.0132 | val_acc 0.5737 | val_f1 0.5554
# Train 6/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 0.9895 | train_acc 0.6150 | train_f1 0.6050 | val_loss 0.9540 | val_acc 0.5800 | val_f1 0.5634
# Train 7/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 0.9306 | train_acc 0.6322 | train_f1 0.6233 | val_loss 0.9198 | val_acc 0.6175 | val_f1 0.6069
# Train 8/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 0.8727 | train_acc 0.6534 | train_f1 0.6468 | val_loss 0.8410 | val_acc 0.6600 | val_f1 0.6455
# Train 9/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 0.8086 | train_acc 0.6897 | train_f1 0.6837 | val_loss 0.7657 | val_acc 0.6825 | val_f1 0.6768
# Train 10/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 0.7305 | train_acc 0.7247 | train_f1 0.7209 | val_loss 0.6541 | val_acc 0.7562 | val_f1 0.7521
# Train 11/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 0.6798 | train_acc 0.7384 | train_f1 0.7343 | val_loss 0.6521 | val_acc 0.7338 | val_f1 0.7293
# Train 12/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 0.6206 | train_acc 0.7688 | train_f1 0.7658 | val_loss 0.5429 | val_acc 0.7913 | val_f1 0.7890
# Train 13/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 0.5885 | train_acc 0.7797 | train_f1 0.7773 | val_loss 0.4881 | val_acc 0.8313 | val_f1 0.8289
# Train 14/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 0.5053 | train_acc 0.8200 | train_f1 0.8181 | val_loss 0.4422 | val_acc 0.8413 | val_f1 0.8414
# Train 15/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 0.4909 | train_acc 0.8228 | train_f1 0.8214 | val_loss 0.4321 | val_acc 0.8375 | val_f1 0.8365
# Train 16/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 0.4274 | train_acc 0.8447 | train_f1 0.8437 | val_loss 0.3737 | val_acc 0.8712 | val_f1 0.8702
# Train 17/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 0.4247 | train_acc 0.8478 | train_f1 0.8467 | val_loss 0.3903 | val_acc 0.8612 | val_f1 0.8584
# Train 18/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 0.3815 | train_acc 0.8684 | train_f1 0.8673 | val_loss 0.3512 | val_acc 0.8662 | val_f1 0.8660
# Train 19/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 0.3503 | train_acc 0.8738 | train_f1 0.8729 | val_loss 0.3202 | val_acc 0.9000 | val_f1 0.8989
# Train 20/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 0.3057 | train_acc 0.8897 | train_f1 0.8887 | val_loss 0.3408 | val_acc 0.8738 | val_f1 0.8708
# Val final/final:   0%|          | 0/25 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 353.03 sec
#
# Final Evaluation
# Val Loss   : 0.3202
# Val Acc    : 0.9000
# Val Prec   : 0.9038
# Val Recall : 0.9000
# Val F1     : 0.8989
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.7634    0.8875    0.8208       160
#          chat     0.8837    0.7125    0.7889       160
# file_transfer     0.9405    0.9875    0.9634       160
#         video     0.9573    0.9812    0.9691       160
#          voip     0.9739    0.9313    0.9521       160
#
#      accuracy                         0.9000       800
#     macro avg     0.9038    0.9000    0.8989       800
#  weighted avg     0.9038    0.9000    0.8989       800
#
# Confusion Matrix:
# [[142  12   2   3   1]
#  [ 44 114   1   0   1]
#  [  0   1 158   1   0]
#  [  0   0   1 157   2]
#  [  0   2   6   3 149]]

# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./1000/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 1000
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.4706 | train_acc 0.3583 | train_f1 0.3489 | val_loss 1.4103 | val_acc 0.3720 | val_f1 0.2991
# Train 2/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 1.3204 | train_acc 0.4602 | train_f1 0.4483 | val_loss 1.2499 | val_acc 0.4790 | val_f1 0.4450
# Train 3/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 1.1642 | train_acc 0.5465 | train_f1 0.5356 | val_loss 1.1392 | val_acc 0.5240 | val_f1 0.5128
# Train 4/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 1.0581 | train_acc 0.5923 | train_f1 0.5818 | val_loss 1.0509 | val_acc 0.5640 | val_f1 0.5417
# Train 5/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 0.9835 | train_acc 0.6112 | train_f1 0.6023 | val_loss 0.9482 | val_acc 0.6160 | val_f1 0.6013
# Train 6/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 0.8938 | train_acc 0.6647 | train_f1 0.6588 | val_loss 0.8860 | val_acc 0.6510 | val_f1 0.6431
# Train 7/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 0.8154 | train_acc 0.6930 | train_f1 0.6891 | val_loss 0.7968 | val_acc 0.7000 | val_f1 0.6911
# Train 8/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 0.7351 | train_acc 0.7310 | train_f1 0.7285 | val_loss 0.6962 | val_acc 0.7250 | val_f1 0.7204
# Train 9/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 0.6654 | train_acc 0.7555 | train_f1 0.7540 | val_loss 0.6142 | val_acc 0.7760 | val_f1 0.7741
# Train 10/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 0.5948 | train_acc 0.7802 | train_f1 0.7783 | val_loss 0.6041 | val_acc 0.7650 | val_f1 0.7635
# Train 11/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 0.5277 | train_acc 0.8147 | train_f1 0.8135 | val_loss 0.5152 | val_acc 0.8270 | val_f1 0.8252
# Train 12/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 0.4736 | train_acc 0.8313 | train_f1 0.8301 | val_loss 0.4117 | val_acc 0.8570 | val_f1 0.8566
# Train 13/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 0.4298 | train_acc 0.8472 | train_f1 0.8465 | val_loss 0.3942 | val_acc 0.8660 | val_f1 0.8642
# Train 14/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 0.3946 | train_acc 0.8650 | train_f1 0.8642 | val_loss 0.3410 | val_acc 0.8930 | val_f1 0.8932
# Train 15/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 0.3426 | train_acc 0.8828 | train_f1 0.8822 | val_loss 0.3238 | val_acc 0.8860 | val_f1 0.8854
# Train 16/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 0.3159 | train_acc 0.8890 | train_f1 0.8886 | val_loss 0.2886 | val_acc 0.9080 | val_f1 0.9079
# Train 17/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 0.2779 | train_acc 0.9083 | train_f1 0.9080 | val_loss 0.2678 | val_acc 0.9120 | val_f1 0.9119
# Train 18/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 0.2591 | train_acc 0.9147 | train_f1 0.9145 | val_loss 0.3069 | val_acc 0.8870 | val_f1 0.8816
# Train 19/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 0.2565 | train_acc 0.9110 | train_f1 0.9108 | val_loss 0.2427 | val_acc 0.9150 | val_f1 0.9151
# Train 20/20:   0%|          | 0/125 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 0.2352 | train_acc 0.9195 | train_f1 0.9193 | val_loss 0.2143 | val_acc 0.9260 | val_f1 0.9260
# Val final/final:   0%|          | 0/32 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 445.85 sec
#
# Final Evaluation
# Val Loss   : 0.2143
# Val Acc    : 0.9260
# Val Prec   : 0.9265
# Val Recall : 0.9260
# Val F1     : 0.9260
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.8349    0.8850    0.8592       200
#          chat     0.8730    0.8250    0.8483       200
# file_transfer     0.9749    0.9700    0.9724       200
#         video     0.9802    0.9900    0.9851       200
#          voip     0.9697    0.9600    0.9648       200
#
#      accuracy                         0.9260      1000
#     macro avg     0.9265    0.9260    0.9260      1000
#  weighted avg     0.9265    0.9260    0.9260      1000
#
# Confusion Matrix:
# [[177  15   4   2   2]
#  [ 35 165   0   0   0]
#  [  0   0 194   2   4]
#  [  0   2   0 198   0]
#  [  0   7   1   0 192]]

# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./1500/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 1500
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.4443 | train_acc 0.3668 | train_f1 0.3456 | val_loss 1.3128 | val_acc 0.5087 | val_f1 0.4959
# Train 2/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 1.2167 | train_acc 0.5083 | train_f1 0.4938 | val_loss 1.1163 | val_acc 0.5653 | val_f1 0.5453
# Train 3/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 1.0599 | train_acc 0.5827 | train_f1 0.5717 | val_loss 0.9522 | val_acc 0.6153 | val_f1 0.6083
# Train 4/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 0.9414 | train_acc 0.6328 | train_f1 0.6256 | val_loss 0.8165 | val_acc 0.6940 | val_f1 0.6892
# Train 5/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 0.7872 | train_acc 0.7075 | train_f1 0.7045 | val_loss 0.7416 | val_acc 0.6840 | val_f1 0.6834
# Train 6/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 0.6616 | train_acc 0.7593 | train_f1 0.7578 | val_loss 0.5788 | val_acc 0.7553 | val_f1 0.7529
# Train 7/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 0.5534 | train_acc 0.7985 | train_f1 0.7979 | val_loss 0.4948 | val_acc 0.8167 | val_f1 0.8161
# Train 8/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 0.4796 | train_acc 0.8313 | train_f1 0.8309 | val_loss 0.4015 | val_acc 0.8580 | val_f1 0.8563
# Train 9/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 0.4171 | train_acc 0.8517 | train_f1 0.8512 | val_loss 0.3569 | val_acc 0.8700 | val_f1 0.8697
# Train 10/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 0.3628 | train_acc 0.8745 | train_f1 0.8742 | val_loss 0.3159 | val_acc 0.8927 | val_f1 0.8928
# Train 11/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 0.3250 | train_acc 0.8867 | train_f1 0.8862 | val_loss 0.3265 | val_acc 0.8887 | val_f1 0.8880
# Train 12/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 0.2793 | train_acc 0.9062 | train_f1 0.9059 | val_loss 0.2642 | val_acc 0.9100 | val_f1 0.9085
# Train 13/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 0.2797 | train_acc 0.9045 | train_f1 0.9042 | val_loss 0.2349 | val_acc 0.9233 | val_f1 0.9225
# Train 14/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 0.2357 | train_acc 0.9222 | train_f1 0.9220 | val_loss 0.2147 | val_acc 0.9307 | val_f1 0.9304
# Train 15/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 0.2110 | train_acc 0.9272 | train_f1 0.9271 | val_loss 0.1978 | val_acc 0.9353 | val_f1 0.9351
# Train 16/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 0.2110 | train_acc 0.9277 | train_f1 0.9275 | val_loss 0.1735 | val_acc 0.9427 | val_f1 0.9424
# Train 17/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 0.1896 | train_acc 0.9330 | train_f1 0.9329 | val_loss 0.1827 | val_acc 0.9440 | val_f1 0.9442
# Train 18/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 0.1865 | train_acc 0.9383 | train_f1 0.9382 | val_loss 0.1777 | val_acc 0.9547 | val_f1 0.9547
# Train 19/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 0.1571 | train_acc 0.9483 | train_f1 0.9482 | val_loss 0.1582 | val_acc 0.9580 | val_f1 0.9578
# Train 20/20:   0%|          | 0/188 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 0.1445 | train_acc 0.9535 | train_f1 0.9534 | val_loss 0.1504 | val_acc 0.9580 | val_f1 0.9578
# Val final/final:   0%|          | 0/47 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 647.32 sec
#
# Final Evaluation
# Val Loss   : 0.1504
# Val Acc    : 0.9580
# Val Prec   : 0.9596
# Val Recall : 0.9580
# Val F1     : 0.9578
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.9814    0.8800    0.9279       300
#          chat     0.9071    0.9767    0.9406       300
# file_transfer     0.9432    0.9967    0.9692       300
#         video     0.9932    0.9667    0.9797       300
#          voip     0.9732    0.9700    0.9716       300
#
#      accuracy                         0.9580      1500
#     macro avg     0.9596    0.9580    0.9578      1500
#  weighted avg     0.9596    0.9580    0.9578      1500
#
# Confusion Matrix:
# [[264  23  11   2   0]
#  [  5 293   1   0   1]
#  [  0   1 299   0   0]
#  [  0   1   2 290   7]
#  [  0   5   4   0 291]]

# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./1600/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 1600
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.4424 | train_acc 0.3697 | train_f1 0.3552 | val_loss 1.3092 | val_acc 0.4338 | val_f1 0.3825
# Train 2/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 1.2127 | train_acc 0.5127 | train_f1 0.5058 | val_loss 1.1080 | val_acc 0.5675 | val_f1 0.5570
# Train 3/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 1.0630 | train_acc 0.5827 | train_f1 0.5737 | val_loss 0.9664 | val_acc 0.5994 | val_f1 0.5830
# Train 4/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 0.9299 | train_acc 0.6380 | train_f1 0.6322 | val_loss 0.8194 | val_acc 0.6681 | val_f1 0.6582
# Train 5/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 0.7877 | train_acc 0.7044 | train_f1 0.7002 | val_loss 0.7107 | val_acc 0.7244 | val_f1 0.7227
# Train 6/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 0.6684 | train_acc 0.7555 | train_f1 0.7536 | val_loss 0.5718 | val_acc 0.7963 | val_f1 0.7956
# Train 7/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 0.5880 | train_acc 0.7784 | train_f1 0.7766 | val_loss 0.4955 | val_acc 0.8213 | val_f1 0.8203
# Train 8/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 0.5124 | train_acc 0.8092 | train_f1 0.8082 | val_loss 0.4077 | val_acc 0.8544 | val_f1 0.8533
# Train 9/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 0.4536 | train_acc 0.8341 | train_f1 0.8330 | val_loss 0.4308 | val_acc 0.8462 | val_f1 0.8492
# Train 10/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 0.3890 | train_acc 0.8595 | train_f1 0.8590 | val_loss 0.3428 | val_acc 0.8831 | val_f1 0.8832
# Train 11/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 0.3387 | train_acc 0.8808 | train_f1 0.8805 | val_loss 0.2914 | val_acc 0.9000 | val_f1 0.9004
# Train 12/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 0.3200 | train_acc 0.8861 | train_f1 0.8857 | val_loss 0.2864 | val_acc 0.9038 | val_f1 0.9042
# Train 13/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 0.2822 | train_acc 0.8994 | train_f1 0.8991 | val_loss 0.2725 | val_acc 0.9056 | val_f1 0.9065
# Train 14/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 0.2533 | train_acc 0.9147 | train_f1 0.9144 | val_loss 0.2098 | val_acc 0.9287 | val_f1 0.9285
# Train 15/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 0.2391 | train_acc 0.9178 | train_f1 0.9177 | val_loss 0.2239 | val_acc 0.9181 | val_f1 0.9181
# Train 16/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 0.2204 | train_acc 0.9234 | train_f1 0.9233 | val_loss 0.2232 | val_acc 0.9213 | val_f1 0.9207
# Train 17/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 0.1901 | train_acc 0.9384 | train_f1 0.9383 | val_loss 0.1779 | val_acc 0.9456 | val_f1 0.9456
# Train 18/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 0.1751 | train_acc 0.9398 | train_f1 0.9397 | val_loss 0.1563 | val_acc 0.9481 | val_f1 0.9480
# Train 19/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 0.1625 | train_acc 0.9463 | train_f1 0.9461 | val_loss 0.1440 | val_acc 0.9550 | val_f1 0.9549
# Train 20/20:   0%|          | 0/200 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 0.1512 | train_acc 0.9500 | train_f1 0.9499 | val_loss 0.1208 | val_acc 0.9681 | val_f1 0.9681
# Val final/final:   0%|          | 0/50 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 686.44 sec
#
# Final Evaluation
# Val Loss   : 0.1208
# Val Acc    : 0.9681
# Val Prec   : 0.9681
# Val Recall : 0.9681
# Val F1     : 0.9681
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.9465    0.9406    0.9436       320
#          chat     0.9528    0.9469    0.9498       320
# file_transfer     0.9845    0.9938    0.9891       320
#         video     0.9811    0.9750    0.9781       320
#          voip     0.9752    0.9844    0.9798       320
#
#      accuracy                         0.9681      1600
#     macro avg     0.9681    0.9681    0.9681      1600
#  weighted avg     0.9681    0.9681    0.9681      1600
#
# Confusion Matrix:
# [[301  14   1   4   0]
#  [ 17 303   0   0   0]
#  [  0   1 318   1   0]
#  [  0   0   0 312   8]
#  [  0   0   4   1 315]]

# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./2000/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 2000
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.4138 | train_acc 0.3912 | train_f1 0.3835 | val_loss 1.2052 | val_acc 0.5375 | val_f1 0.5297
# Train 2/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 1.1408 | train_acc 0.5489 | train_f1 0.5377 | val_loss 1.0116 | val_acc 0.5940 | val_f1 0.5751
# Train 3/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 0.9684 | train_acc 0.6172 | train_f1 0.6097 | val_loss 0.8281 | val_acc 0.6970 | val_f1 0.6924
# Train 4/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 0.8049 | train_acc 0.6975 | train_f1 0.6944 | val_loss 0.6404 | val_acc 0.7800 | val_f1 0.7794
# Train 5/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 0.6644 | train_acc 0.7540 | train_f1 0.7527 | val_loss 0.5246 | val_acc 0.8190 | val_f1 0.8183
# Train 6/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 0.5443 | train_acc 0.8000 | train_f1 0.7993 | val_loss 0.4250 | val_acc 0.8485 | val_f1 0.8499
# Train 7/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 0.4573 | train_acc 0.8345 | train_f1 0.8339 | val_loss 0.3714 | val_acc 0.8670 | val_f1 0.8673
# Train 8/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 0.3895 | train_acc 0.8612 | train_f1 0.8608 | val_loss 0.2878 | val_acc 0.9000 | val_f1 0.8990
# Train 9/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 0.3379 | train_acc 0.8809 | train_f1 0.8805 | val_loss 0.2575 | val_acc 0.9110 | val_f1 0.9101
# Train 10/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 0.2848 | train_acc 0.8990 | train_f1 0.8987 | val_loss 0.2074 | val_acc 0.9365 | val_f1 0.9363
# Train 11/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 0.2588 | train_acc 0.9106 | train_f1 0.9105 | val_loss 0.1956 | val_acc 0.9365 | val_f1 0.9363
# Train 12/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 0.2258 | train_acc 0.9255 | train_f1 0.9253 | val_loss 0.1671 | val_acc 0.9450 | val_f1 0.9444
# Train 13/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 0.2039 | train_acc 0.9316 | train_f1 0.9315 | val_loss 0.1812 | val_acc 0.9375 | val_f1 0.9367
# Train 14/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 0.1776 | train_acc 0.9394 | train_f1 0.9392 | val_loss 0.1570 | val_acc 0.9390 | val_f1 0.9387
# Train 15/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 0.1639 | train_acc 0.9437 | train_f1 0.9437 | val_loss 0.1136 | val_acc 0.9640 | val_f1 0.9639
# Train 16/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 0.1379 | train_acc 0.9560 | train_f1 0.9559 | val_loss 0.0886 | val_acc 0.9740 | val_f1 0.9740
# Train 17/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 0.1249 | train_acc 0.9604 | train_f1 0.9603 | val_loss 0.1073 | val_acc 0.9660 | val_f1 0.9657
# Train 18/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 0.1195 | train_acc 0.9590 | train_f1 0.9589 | val_loss 0.0765 | val_acc 0.9810 | val_f1 0.9809
# Train 19/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 0.1098 | train_acc 0.9637 | train_f1 0.9637 | val_loss 0.0796 | val_acc 0.9780 | val_f1 0.9778
# Train 20/20:   0%|          | 0/250 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 0.1006 | train_acc 0.9686 | train_f1 0.9686 | val_loss 0.0700 | val_acc 0.9815 | val_f1 0.9814
# Val final/final:   0%|          | 0/63 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 860.31 sec
#
# Final Evaluation
# Val Loss   : 0.0700
# Val Acc    : 0.9815
# Val Prec   : 0.9820
# Val Recall : 0.9815
# Val F1     : 0.9814
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.9947    0.9300    0.9612       400
#          chat     0.9475    0.9925    0.9695       400
# file_transfer     0.9804    1.0000    0.9901       400
#         video     0.9926    1.0000    0.9963       400
#          voip     0.9949    0.9850    0.9899       400
#
#      accuracy                         0.9815      2000
#     macro avg     0.9820    0.9815    0.9814      2000
#  weighted avg     0.9820    0.9815    0.9814      2000
#
# Confusion Matrix:
# [[372  19   6   2   1]
#  [  1 397   1   0   1]
#  [  0   0 400   0   0]
#  [  0   0   0 400   0]
#  [  1   3   1   1 394]]

# %%
import os
import time
import random
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from thop import profile, clever_format
from kan_convolutional.KANLinear import KANLinear


DATA_ROOT = r"C:\Users\rscha\OneDrive\Desktop\anurag\NTC\rp_aug_reg"
SAVE_DIR = r"./3200/reg/vitkan_small_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

CLASS_NAMES = ["browsing", "chat", "file_transfer", "video", "voip"]
CLASS_TO_IDX = {c: i for i, c in enumerate(CLASS_NAMES)}

MAX_PER_CLASS = 3200
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANS = 1
NUM_CLASSES = 5

EMBED_DIM = 64
DEPTH = 2
NUM_HEADS = 4
MLP_RATIO = 2.0

DROP_RATE = 0.1
ATTN_DROP = 0.1
DROP_PATH = 0.0

BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 0
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_best.pth")
LAST_MODEL_PATH = os.path.join(SAVE_DIR, "vitkan_last.pth")
HISTORY_CSV_PATH = os.path.join(SAVE_DIR, "vitkan_history.csv")
CM_PNG_PATH = os.path.join(SAVE_DIR, "vitkan_confusion_matrix.png")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


class TrafficRPDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("L")
        if self.transform:
            image = self.transform(image)
        return image, label


def collect_and_subsample(data_root, class_names, max_per_class):
    per_class = collections.defaultdict(list)

    for cls in class_names:
        cls_dir = os.path.join(data_root, cls)
        for root, _, files in os.walk(cls_dir):
            for f in files:
                if f.lower().endswith((".png", ".jpg", ".jpeg")):
                    img_path = os.path.join(root, f)
                    per_class[cls].append((img_path, CLASS_TO_IDX[cls]))

    samples = []
    for cls in class_names:
        cls_samples = per_class[cls]
        if len(cls_samples) > max_per_class:
            cls_samples = random.sample(cls_samples, max_per_class)
        samples.extend(cls_samples)

    return samples


samples = collect_and_subsample(DATA_ROOT, CLASS_NAMES, MAX_PER_CLASS)

train_samples, val_samples = train_test_split(
    samples,
    test_size=0.2,
    random_state=SEED,
    stratify=[y for _, y in samples]
)

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = TrafficRPDataset(train_samples, transform=train_transform)
val_dataset = TrafficRPDataset(val_samples, transform=val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)


def compute_metrics(y_true, y_pred):
    return {
        "acc": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable


class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor


class PatchEmbed(nn.Module):
    def __init__(self, img_size=224, patch_size=16, in_chans=1, embed_dim=128):
        super().__init__()
        self.num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.proj = nn.Conv2d(
            in_chans,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x


class Attention(nn.Module):
    def __init__(self, dim, num_heads=4, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        b, n, c = x.shape
        qkv = self.qkv(x).reshape(b, n, 3, self.num_heads, c // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(b, n, c)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class KANFeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, drop=0.0):
        super().__init__()
        self.kan1 = KANLinear(
            in_features=dim,
            out_features=hidden_dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.kan2 = KANLinear(
            in_features=hidden_dim,
            out_features=dim,
            grid_size=5,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[-1, 1]
        )
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        b, n, c = x.shape
        x = x.reshape(b * n, c)
        x = self.kan1(x)
        x = self.drop(x)
        x = self.kan2(x)
        x = self.drop(x)
        x = x.reshape(b, n, c)
        return x


class ViTKANBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2.0, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path1 = DropPath(drop_path)

        self.norm2 = nn.LayerNorm(dim)
        hidden_dim = int(dim * mlp_ratio)
        self.kan_ffn = KANFeedForward(dim=dim, hidden_dim=hidden_dim, drop=drop)
        self.drop_path2 = DropPath(drop_path)

    def forward(self, x):
        x = x + self.drop_path1(self.attn(self.norm1(x)))
        x = x + self.drop_path2(self.kan_ffn(self.norm2(x)))
        return x


class ViTKAN(nn.Module):
    def __init__(
        self,
        img_size=224,
        patch_size=16,
        in_chans=1,
        num_classes=5,
        embed_dim=128,
        depth=4,
        num_heads=4,
        mlp_ratio=2.0,
        drop_rate=0.1,
        attn_drop_rate=0.1,
        drop_path_rate=0.0
    ):
        super().__init__()

        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim
        )

        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            ViTKANBlock(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i]
            )
            for i in range(depth)
        ])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.bias, 0)
                nn.init.constant_(m.weight, 1.0)

    def forward_features(self, x):
        b = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):
        cls_feat = self.forward_features(x)
        return self.head(cls_feat)


def count_kanlinear(m, x, y):
    inp = x[0]
    batch_elems = inp.shape[0]
    in_features = m.in_features
    out_features = m.out_features
    macs = batch_elems * in_features * out_features
    m.total_ops += torch.DoubleTensor([macs])


def profile_model(model, device, img_size, in_chans):
    model.eval()
    dummy = torch.randn(1, in_chans, img_size, img_size).to(device)
    macs, params = profile(
        model,
        inputs=(dummy,),
        custom_ops={KANLinear: count_kanlinear},
        verbose=False
    )
    flops = macs * 2
    macs_str, params_str = clever_format([macs, params], "%.3f")
    flops_str, _ = clever_format([flops, params], "%.3f")
    return macs, flops, params, macs_str, flops_str, params_str


def train_one_epoch(model, loader, optimizer, criterion, device, epoch, epochs):
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Train {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        logits = model(images)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device, epoch, epochs):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    pbar = tqdm(loader, desc=f"Val {epoch}/{epochs}", leave=False)

    for batch_idx, (images, labels) in enumerate(pbar, start=1):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

        running_loss += loss.item()
        metrics = compute_metrics(all_labels, all_preds)

        pbar.set_postfix(
            loss=f"{running_loss / batch_idx:.4f}",
            acc=f"{metrics['acc']:.4f}",
            f1=f"{metrics['f1']:.4f}"
        )

    epoch_loss = running_loss / len(loader)
    epoch_metrics = compute_metrics(all_labels, all_preds)
    return epoch_loss, epoch_metrics, np.array(all_labels), np.array(all_preds)


model = ViTKAN(
    img_size=IMG_SIZE,
    patch_size=PATCH_SIZE,
    in_chans=IN_CHANS,
    num_classes=NUM_CLASSES,
    embed_dim=EMBED_DIM,
    depth=DEPTH,
    num_heads=NUM_HEADS,
    mlp_ratio=MLP_RATIO,
    drop_rate=DROP_RATE,
    attn_drop_rate=ATTN_DROP,
    drop_path_rate=DROP_PATH
).to(DEVICE)

total_params, trainable_params = count_parameters(model)
macs, flops, thop_params, macs_str, flops_str, params_str = profile_model(
    model, DEVICE, IMG_SIZE, IN_CHANS
)

print(f"Params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

history = []
best_val_f1 = -1.0
start_time = time.time()

for epoch in range(1, EPOCHS + 1):
    train_start = time.time()
    train_loss, train_metrics = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    train_time = time.time() - train_start

    val_start = time.time()
    val_loss, val_metrics, y_true, y_pred = validate_one_epoch(
        model=model,
        loader=val_loader,
        criterion=criterion,
        device=DEVICE,
        epoch=epoch,
        epochs=EPOCHS
    )
    val_time = time.time() - val_start

    history.append({
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_metrics["acc"],
        "train_precision": train_metrics["precision"],
        "train_recall": train_metrics["recall"],
        "train_f1": train_metrics["f1"],
        "val_loss": val_loss,
        "val_acc": val_metrics["acc"],
        "val_precision": val_metrics["precision"],
        "val_recall": val_metrics["recall"],
        "val_f1": val_metrics["f1"],
        "train_time_sec": train_time,
        "val_time_sec": val_time,
        "params": total_params,
        "macs": macs,
        "flops": flops
    })

    print(
        f"Epoch {epoch:02d}/{EPOCHS} | "
        f"train_loss {train_loss:.4f} | train_acc {train_metrics['acc']:.4f} | train_f1 {train_metrics['f1']:.4f} | "
        f"val_loss {val_loss:.4f} | val_acc {val_metrics['acc']:.4f} | val_f1 {val_metrics['f1']:.4f}"
    )

    torch.save(model.state_dict(), LAST_MODEL_PATH)

    if val_metrics["f1"] > best_val_f1:
        best_val_f1 = val_metrics["f1"]
        torch.save(model.state_dict(), BEST_MODEL_PATH)

    pd.DataFrame(history).to_csv(HISTORY_CSV_PATH, index=False)

total_time = time.time() - start_time

model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)

final_val_loss, final_metrics, y_true, y_pred = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    epoch="final",
    epochs="final"
)

print()
print(f"Params: {total_params:,}")
print(f"MACs: {macs_str}")
print(f"FLOPs: {flops_str}")
print(f"Training time: {total_time:.2f} sec")
print()
print("Final Evaluation")
print(f"Val Loss   : {final_val_loss:.4f}")
print(f"Val Acc    : {final_metrics['acc']:.4f}")
print(f"Val Prec   : {final_metrics['precision']:.4f}")
print(f"Val Recall : {final_metrics['recall']:.4f}")
print(f"Val F1     : {final_metrics['f1']:.4f}")
print()
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ViT-KAN Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_PNG_PATH, dpi=300)
plt.show()
# Out:
# Params: 391,045
# Trainable params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Train 1/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 1/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 01/20 | train_loss 1.3289 | train_acc 0.4460 | train_f1 0.4390 | val_loss 1.0838 | val_acc 0.5775 | val_f1 0.5624
# Train 2/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 2/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 02/20 | train_loss 0.9884 | train_acc 0.6114 | train_f1 0.6032 | val_loss 0.7962 | val_acc 0.6913 | val_f1 0.6861
# Train 3/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 3/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 03/20 | train_loss 0.7304 | train_acc 0.7260 | train_f1 0.7235 | val_loss 0.5264 | val_acc 0.8047 | val_f1 0.8048
# Train 4/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 4/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 04/20 | train_loss 0.5415 | train_acc 0.8023 | train_f1 0.8012 | val_loss 0.3759 | val_acc 0.8756 | val_f1 0.8759
# Train 5/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 5/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 05/20 | train_loss 0.4068 | train_acc 0.8583 | train_f1 0.8574 | val_loss 0.2836 | val_acc 0.9050 | val_f1 0.9043
# Train 6/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 6/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 06/20 | train_loss 0.3118 | train_acc 0.8923 | train_f1 0.8919 | val_loss 0.2100 | val_acc 0.9234 | val_f1 0.9232
# Train 7/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 7/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 07/20 | train_loss 0.2520 | train_acc 0.9136 | train_f1 0.9134 | val_loss 0.1541 | val_acc 0.9444 | val_f1 0.9442
# Train 8/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 8/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 08/20 | train_loss 0.2068 | train_acc 0.9284 | train_f1 0.9282 | val_loss 0.1577 | val_acc 0.9375 | val_f1 0.9373
# Train 9/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 9/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 09/20 | train_loss 0.1750 | train_acc 0.9395 | train_f1 0.9394 | val_loss 0.1217 | val_acc 0.9553 | val_f1 0.9552
# Train 10/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 10/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 10/20 | train_loss 0.1451 | train_acc 0.9513 | train_f1 0.9512 | val_loss 0.1010 | val_acc 0.9688 | val_f1 0.9684
# Train 11/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 11/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 11/20 | train_loss 0.1200 | train_acc 0.9630 | train_f1 0.9629 | val_loss 0.0887 | val_acc 0.9712 | val_f1 0.9711
# Train 12/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 12/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 12/20 | train_loss 0.1114 | train_acc 0.9626 | train_f1 0.9625 | val_loss 0.0971 | val_acc 0.9697 | val_f1 0.9691
# Train 13/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 13/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 13/20 | train_loss 0.0890 | train_acc 0.9724 | train_f1 0.9724 | val_loss 0.0804 | val_acc 0.9722 | val_f1 0.9718
# Train 14/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 14/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 14/20 | train_loss 0.0862 | train_acc 0.9727 | train_f1 0.9726 | val_loss 0.0535 | val_acc 0.9831 | val_f1 0.9831
# Train 15/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 15/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 15/20 | train_loss 0.0915 | train_acc 0.9707 | train_f1 0.9706 | val_loss 0.0691 | val_acc 0.9778 | val_f1 0.9777
# Train 16/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 16/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 16/20 | train_loss 0.0692 | train_acc 0.9784 | train_f1 0.9783 | val_loss 0.0679 | val_acc 0.9806 | val_f1 0.9805
# Train 17/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 17/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 17/20 | train_loss 0.0737 | train_acc 0.9754 | train_f1 0.9754 | val_loss 0.0624 | val_acc 0.9819 | val_f1 0.9818
# Train 18/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 18/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 18/20 | train_loss 0.0565 | train_acc 0.9825 | train_f1 0.9825 | val_loss 0.0748 | val_acc 0.9766 | val_f1 0.9765
# Train 19/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 19/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 19/20 | train_loss 0.0606 | train_acc 0.9807 | train_f1 0.9807 | val_loss 0.0564 | val_acc 0.9844 | val_f1 0.9843
# Train 20/20:   0%|          | 0/400 [00:00<?, ?it/s]
# Val 20/20:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 20/20 | train_loss 0.0549 | train_acc 0.9830 | train_f1 0.9829 | val_loss 0.0470 | val_acc 0.9859 | val_f1 0.9858
# Val final/final:   0%|          | 0/100 [00:00<?, ?it/s]
# Params: 391,045
# MACs: 16.374M
# FLOPs: 32.749M
# Training time: 1385.15 sec
#
# Final Evaluation
# Val Loss   : 0.0470
# Val Acc    : 0.9859
# Val Prec   : 0.9863
# Val Recall : 0.9859
# Val F1     : 0.9858
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing     0.9983    0.9375    0.9670       640
#          chat     0.9581    1.0000    0.9786       640
# file_transfer     0.9846    0.9984    0.9915       640
#         video     0.9922    0.9984    0.9953       640
#          voip     0.9984    0.9953    0.9969       640
#
#      accuracy                         0.9859      3200
#     macro avg     0.9863    0.9859    0.9858      3200
#  weighted avg     0.9863    0.9859    0.9858      3200
#
# Confusion Matrix:
# [[600  27   9   3   1]
#  [  0 640   0   0   0]
#  [  1   0 639   0   0]
#  [  0   0   1 639   0]
#  [  0   1   0   2 637]]
